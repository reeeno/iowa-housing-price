# %% [markdown]
# ## Set up
# ### Importing libraries

# %%
import numpy as np
import pandas as pd
from pandas.api.types import is_numeric_dtype
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error as mse
from sklearn.linear_model import LinearRegression, Ridge, Lasso

# %% [markdown]
# ### Data load & enrichment

# %%
data_folder = '.'

additional_features = pd.read_csv(f"{data_folder}/data.csv").drop("Id", axis=1)
additional_features = additional_features.fillna(additional_features.mean())
additional_features = additional_features.fillna('N/A')
base_features = pd.read_csv(f"{data_folder}/Houseprice_data_scaled.csv")

# %% [markdown]
# ### Parameters & Constants

# %%
# Params
SHOW_CAT_TO_NUM_WARNING = False
ADDITIONAL_FEATURES_SELECT = ['MSZoning', 'MSSubClass']
LAMBDA_RIDGE = 0.1
LAMBDA_LASSO = 0.04
N_SIMULATIONS = 1000

# Constants
ADDITIONAL_FEATURES_FIXED = ['LotFrontage', 'LotShape']
ADDITIONAL_FEATURES = ADDITIONAL_FEATURES_FIXED + ADDITIONAL_FEATURES_SELECT

# %% [markdown]
# ### Helper functions

# %%
def add_features(base, feature_name):
    """ 
    Outputs a dataframe which equals base_features plus any feature_name from additional_features. 
    Any categorical features will be naively converts to numerical values. All the feature values will be scaled.
    Any missing values (N/A) are filled with average values for this feature
    """
    rep_base = base.copy()
    def add_single_feature(single_feature):
        if is_numeric_dtype(additional_features[single_feature].dtype):
            rep_base[single_feature] = additional_features[single_feature]
        else:
            flist = np.setdiff1d(additional_features[single_feature].unique(), ['N/A'])
            f_map = dict(zip(flist, range(len(flist))))
            if SHOW_CAT_TO_NUM_WARNING:
                print("Warning: feature {} is categorical. Mapping to numerical...".format(single_feature))
                print("Mapping: {}".format(f_map))    
            rep_base[single_feature] = additional_features[single_feature].map(f_map)
            # TODO: what to do for NA in categorical features?
            rep_base[single_feature] = rep_base[single_feature].replace('N/A', np.nan)
            rep_base[single_feature] = rep_base[single_feature].fillna(rep_base[single_feature].mean())
        rep_base[single_feature] = (rep_base[single_feature] - rep_base[single_feature].mean()) / rep_base[single_feature].std()
    if type(feature_name) == str:
        add_single_feature(feature_name)
    elif type(feature_name) == list:
        for f in feature_name:
            add_single_feature(f)
    return rep_base

def split_dataset(dataset, random=False):
    """ Split input dataset into training, validation and test set (in this order) of size 1800, 600 and whatever left """
    idx_lst = np.arange(len(dataset))
    if random:
        np.random.shuffle(idx_lst)
    train_idx = idx_lst[:1800]
    val_idx = idx_lst[1800:1800+600]
    test_idx = idx_lst[1800+600:len(dataset)]
    return dataset.iloc[train_idx], dataset.iloc[val_idx], dataset.iloc[test_idx]

def split_xy(dataset, value_name="Sale Price"):
    """ Split input data set into feature and value """
    return dataset.drop(value_name, axis=1), dataset[[value_name]]

def regression(features, method='linear', alpha=0, random=False):
    """ 
    Run a regression of choice with additional features added to base_features
    
    :param features: A list of features available in dataframe additional_features
    :param method: One of "linear", "ridge" or "lasso"
    :param alpha: Alpha pamameter used for ridge or lasso regression. Should be lambda in Hull's book times # of 
                  observations for ridge regression or half of lambda for lasso regression.
    :param random: Whether to split training/validation/test data sets randomly or not
    
    :return: A dictionary containing coeffients and model mse
    """
    # Select features
    df = add_features(base_features, ADDITIONAL_FEATURES)
    
    # Split data set and split each into X and y where y is the price, and X is set of features
    train, val, test = [split_xy(x) for x in split_dataset(df, random=random)]
    
    # Fit model
    def fit_model(alpha):
        reg_model = {
            'linear': LinearRegression(),
            'ridge': Ridge(alpha=alpha),
            'lasso': Lasso(alpha=alpha),
        }[method.lower()]
        reg_model.fit(*train)
    
        return {
            'coeffs': pd.DataFrame(
                [
                    ['intercept'] + list(train[0]),
                    list(reg_model.intercept_) + list(reg_model.coef_ if method == 'lasso' else reg_model.coef_[0])
                ]
            ).transpose().set_index(0),
            'mse': mse(val[1], reg_model.predict(val[0])),
        }
    
    try:
        return fit_model(float(alpha))
    except TypeError:
        return [fit_model(float(a)) for a in alpha]

def monte_carlo(features, n_simulations, method="linear", alpha=0):
    """
    Run Monte Carlo simulations for a particular regression method and output the average mses and coeffs
    """
    def mc_single_alpha(features, n_simulations, method, alpha):
        coeffs = []
        mses = []
        for i in range(n_simulations):
            rs = regression(features, method=method, alpha=alpha, random=True)
            coeffs.append(rs['coeffs'])
            mses.append(rs['mse'])    
        return {
            'coeffs': pd.DataFrame(pd.concat(coeffs, axis=1).mean(axis=1)),
            'mse': np.array(mses).mean(),
        }
    try:
        return mc_single_alpha(features, n_simulations, method, float(alpha))
    except TypeError:
        return [mc_single_alpha(features, n_simulations, method, float(a)) for a in alpha]

# %% [markdown]
# ## Regression Analysis I
#
# Use first 1800 as training set, next 800 as validation set and the rest as test set
#
# ### Linear Regression

# %%
regression(ADDITIONAL_FEATURES_SELECT, method='linear')['coeffs']
# Out:
#                          1
# 0
# intercept       -0.0145748
# LotArea          0.0614796
# OverallQual       0.211643
# OverallCond      0.0879999
# YearBuilt         0.162659
# YearRemodAdd     0.0262192
# BsmtFinSF1       0.0982617
# BsmtUnfSF       -0.0369657
# TotalBsmtSF       0.114031
# 1stFlrSF          0.127911
# 2ndFlrSF          0.142371
# GrLivArea         0.192903
# FullBath        -0.0019991
# HalfBath         0.0147251
# BedroomAbvGr    -0.0967823
# TotRmsAbvGrd     0.0686037
# Fireplaces       0.0224426
# GarageCars       0.0487009
# GarageArea       0.0260745
# WoodDeckSF       0.0189636
# OpenPorchSF      0.0309564
# EnclosedPorch   0.00289364
# Blmngtn        0.000101811
# Blueste        -0.00240691
# BrDale          0.00282316
# BrkSide           0.017264
# ClearCr        -0.00760527
# CollgCr         -0.0184424
# Crawfor          0.0390621
# Edwards        -0.00357208
# Gilbert         -0.0206404
# IDOTRR         -0.00371843
# MeadowV          0.0121137
# Mitchel         -0.0291789
# Names           -0.0474697
# NoRidge          0.0423583
# NPkVill        0.000237122
# NriddgHt          0.124998
# NWAmes          -0.0555393
# OLDTown         -0.0247285
# SWISU         -0.000713882
# Sawyer           -0.024501
# SawyerW         -0.0324272
# Somerst          0.0363995
# StoneBr          0.0784471
# Timber         -0.00803265
# Veenker          0.0054665
# Bsmt Qual        0.0193818
# LotFrontage      0.0303694
# LotShape        0.00609753
# MSZoning        0.00457837
# MSSubClass       -0.110039

# %% [markdown]
# ### Ridge Regression

# %%
lambdas = np.arange(0.01, 0.2, 0.01)
alphas = lambdas * 1800

mses = [x['mse'] for x in regression(ADDITIONAL_FEATURES_SELECT, method='ridge', alpha=alphas)]

plt.plot(lambdas, mses)
plt.show()

regression(ADDITIONAL_FEATURES_SELECT, method='ridge', alpha=LAMBDA_RIDGE*1800)['coeffs']
# Out:
#                          1
# 0
# intercept       -0.0147715
# LotArea          0.0559309
# OverallQual       0.193224
# OverallCond      0.0693546
# YearBuilt         0.105469
# YearRemodAdd     0.0467749
# BsmtFinSF1        0.104148
# BsmtUnfSF        -0.022468
# TotalBsmtSF      0.0972576
# 1stFlrSF          0.109696
# 2ndFlrSF         0.0951502
# GrLivArea         0.166205
# FullBath         0.0208246
# HalfBath         0.0310945
# BedroomAbvGr         -0.07
# TotRmsAbvGrd     0.0723683
# Fireplaces       0.0377975
# GarageCars       0.0482356
# GarageArea       0.0466221
# WoodDeckSF       0.0237392
# OpenPorchSF      0.0347632
# EnclosedPorch -0.000179472
# Blmngtn        -0.00136323
# Blueste        -0.00345621
# BrDale         0.000211264
# BrkSide          0.0124377
# ClearCr        -0.00430016
# CollgCr          -0.012005
# Crawfor          0.0355354
# Edwards        -0.00598725
# Gilbert         -0.0185617
# IDOTRR         -0.00975094
# MeadowV          0.0051466
# Mitchel         -0.0273179
# Names           -0.0424347
# NoRidge          0.0490573
# NPkVill        -0.00538913
# NriddgHt          0.119285
# NWAmes          -0.0496712
# OLDTown         -0.0298932
# SWISU          -0.00542043
# Sawyer          -0.0246322
# SawyerW         -0.0265792
# Somerst          0.0339739
# StoneBr          0.0760373
# Timber         -0.00400476
# Veenker          0.0083218
# Bsmt Qual        0.0421107
# LotFrontage      0.0324045
# LotShape        0.00166027
# MSZoning        0.00273017
# MSSubClass      -0.0861173

# %% [markdown]
# ### Lasso Regression

# %%
lambdas = np.arange(0.01, 0.2, 0.01)
alphas = lambdas / 2

mses = [x['mse'] for x in regression(ADDITIONAL_FEATURES_SELECT, method='lasso', alpha=alphas)]

plt.plot(lambdas, mses)
plt.show()

regression(ADDITIONAL_FEATURES_SELECT, method='lasso', alpha=LAMBDA_LASSO/2)['coeffs']
# Out:
#                         1
# 0
# intercept      -0.0142667
# LotArea         0.0527082
# OverallQual      0.254299
# OverallCond     0.0419465
# YearBuilt        0.106387
# YearRemodAdd    0.0480002
# BsmtFinSF1       0.124145
# BsmtUnfSF              -0
# TotalBsmtSF     0.0840229
# 1stFlrSF       0.00802639
# 2ndFlrSF                0
# GrLivArea        0.351853
# FullBath                0
# HalfBath                0
# BedroomAbvGr    -0.038808
# TotRmsAbvGrd   0.00234474
# Fireplaces      0.0241765
# GarageCars      0.0390531
# GarageArea      0.0408183
# WoodDeckSF      0.0127569
# OpenPorchSF     0.0188338
# EnclosedPorch          -0
# Blmngtn                 0
# Blueste                -0
# BrDale                 -0
# BrkSide        0.00293267
# ClearCr                 0
# CollgCr                -0
# Crawfor         0.0275266
# Edwards                 0
# Gilbert                -0
# IDOTRR                 -0
# MeadowV                 0
# Mitchel                -0
# Names         -0.00328898
# NoRidge         0.0373541
# NPkVill                -0
# NriddgHt         0.120973
# NWAmes         -0.0182227
# OLDTown                -0
# SWISU                  -0
# Sawyer                 -0
# SawyerW                -0
# Somerst         0.0221366
# StoneBr         0.0590389
# Timber                  0
# Veenker                 0
# Bsmt Qual       0.0247534
# LotFrontage     0.0105011
# LotShape               -0
# MSZoning               -0
# MSSubClass     -0.0733608

# %% [markdown]
# ## Regression Analysis II
#
# Randomly determine training set, validation set and test set
# TODO: MONTE CARLO THIS SHIT!
#
# ### Linear Regression

# %%
monte_carlo(ADDITIONAL_FEATURES_SELECT, N_SIMULATIONS, method='linear')['coeffs']
# Out:
#                           0
# 0
# intercept      4.422683e-05
# LotArea        6.467318e-02
# OverallQual    2.243563e-01
# OverallCond    7.945630e-02
# YearBuilt      1.611990e-01
# YearRemodAdd   3.513384e-02
# BsmtFinSF1     8.563648e-02
# BsmtUnfSF     -5.784797e-02
# TotalBsmtSF    1.240338e-01
# 1stFlrSF       1.408605e-01
# 2ndFlrSF       1.508564e-01
# GrLivArea      1.937718e-01
# FullBath       4.607369e-03
# HalfBath       1.026833e-02
# BedroomAbvGr  -8.202862e-02
# TotRmsAbvGrd   4.154777e-02
# Fireplaces     2.195802e-02
# GarageCars     1.175922e-02
# GarageArea     6.202516e-02
# WoodDeckSF     1.985874e-02
# OpenPorchSF    1.019082e-02
# EnclosedPorch  3.491396e-03
# Blmngtn        3.589601e+08
# Blueste        2.151890e+08
# BrDale         3.714299e+08
# BrkSide        6.920211e+08
# ClearCr        4.487286e+08
# CollgCr        1.061477e+09
# Crawfor        6.762617e+08
# Edwards        9.106099e+08
# Gilbert        8.504049e+08
# IDOTRR         6.365941e+08
# MeadowV        4.119916e+08
# Mitchel        7.134056e+08
# Names          1.320934e+09
# NoRidge        5.594717e+08
# NPkVill        3.256175e+08
# NriddgHt       8.504049e+08
# NWAmes         7.624203e+08
# OLDTown        1.009588e+09
# SWISU          4.683543e+08
# Sawyer         8.156010e+08
# SawyerW        7.455598e+08
# Somerst        8.903679e+08
# StoneBr        4.825153e+08
# Timber         5.712027e+08
# Veenker        3.325631e+08
# Bsmt Qual      3.482533e-02
# LotFrontage    3.016309e-02
# LotShape       4.127108e-04
# MSZoning      -9.562502e-03
# MSSubClass    -1.026631e-01

# %% [markdown]
# ### Ridge Regression

# %%
lambdas = np.arange(0.01, 0.2, 0.01)
alphas = lambdas * 1800

mses = [x['mse'] for x in monte_carlo(ADDITIONAL_FEATURES_SELECT, N_SIMULATIONS, method='ridge', alpha=alphas)]

plt.plot(lambdas, mses)
plt.show()

monte_carlo(ADDITIONAL_FEATURES_SELECT, method='ridge', alpha=LAMBDA_RIDGE*1800)['coeffs']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-a45c9c570f49> in monte_carlo(features, n_simulations, method, alpha)
#     100     try:
# --> 101         return mc_single_alpha(features, n_simulations, method, float(alpha))
#     102     except TypeError:
#
# TypeError: only size-1 arrays can be converted to Python scalars
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-bb67a4634f12> in <module>
#       2 alphas = lambdas * 1800
#       3
# ----> 4 mses = [x['mse'] for x in monte_carlo(ADDITIONAL_FEATURES_SELECT, N_SIMULATIONS, method='ridge', alpha=alphas)]
#       5
#       6 plt.plot(lambdas, mses)
#
# <ipython-input-64-a45c9c570f49> in monte_carlo(features, n_simulations, method, alpha)
#     101         return mc_single_alpha(features, n_simulations, method, float(alpha))
#     102     except TypeError:
# --> 103         return [mc_single_alpha(features, n_simulations, method, float(a)) for a in alpha]
#
# <ipython-input-64-a45c9c570f49> in <listcomp>(.0)
#     101         return mc_single_alpha(features, n_simulations, method, float(alpha))
#     102     except TypeError:
# --> 103         return [mc_single_alpha(features, n_simulations, method, float(a)) for a in alpha]
#
# <ipython-input-64-a45c9c570f49> in mc_single_alpha(features, n_simulations, method, alpha)
#      91         mses = []
#      92         for i in range(n_simulations):
# ---> 93             rs = regression(features, method=method, alpha=alpha, random=True)
#      94             coeffs.append(rs['coeffs'])
#      95             mses.append(rs['mse'])
#
# <ipython-input-64-a45c9c570f49> in regression(features, method, alpha, random)
#      57
#      58     # Split data set and split each into X and y where y is the price, and X is set of features
# ---> 59     train, val, test = [split_xy(x) for x in split_dataset(df, random=random)]
#      60
#      61     # Fit model
#
# <ipython-input-64-a45c9c570f49> in split_dataset(dataset, random)
#      35     val_idx = idx_lst[1800:1800+600]
#      36     test_idx = idx_lst[1800+600:len(dataset)]
# ---> 37     return dataset.iloc[train_idx], dataset.iloc[val_idx], dataset.iloc[test_idx]
#      38
#      39 def split_xy(dataset, value_name="Sale Price"):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2219         # a list of integers
#    2220         elif is_list_like_indexer(key):
# -> 2221             return self._get_list_axis(key, axis=axis)
#    2222
#    2223         # a single integer
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _get_list_axis(self, key, axis)
#    2198             axis = self.axis or 0
#    2199         try:
# -> 2200             return self.obj._take(key, axis=axis)
#    2201         except IndexError:
#    2202             # re-raise with different error message
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in _take(self, indices, axis, is_copy)
#    3357         new_data = self._data.take(indices,
#    3358                                    axis=self._get_block_manager_axis(axis),
# -> 3359                                    verify=True)
#    3360         result = self._constructor(new_data).__finalize__(self)
#    3361
#
# /usr/local/lib/python3.7/site-packages/pandas/core/internals/managers.py in take(self, indexer, axis, verify, convert)
#    1348         new_labels = self.axes[axis].take(indexer)
#    1349         return self.reindex_indexer(new_axis=new_labels, indexer=indexer,
# -> 1350                                     axis=axis, allow_dups=True)
#    1351
#    1352     def merge(self, other, lsuffix='', rsuffix=''):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1233             new_blocks = [blk.take_nd(indexer, axis=axis, fill_tuple=(
#    1234                 fill_value if fill_value is not None else blk.fill_value,))
# -> 1235                 for blk in self.blocks]
#    1236
#    1237         new_axes = list(self.axes)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#    1233             new_blocks = [blk.take_nd(indexer, axis=axis, fill_tuple=(
#    1234                 fill_value if fill_value is not None else blk.fill_value,))
# -> 1235                 for blk in self.blocks]
#    1236
#    1237         new_axes = list(self.axes)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/internals/blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_tuple)
#    1236             fill_value = fill_tuple[0]
#    1237             new_values = algos.take_nd(values, indexer, axis=axis,
# -> 1238                                        allow_fill=True, fill_value=fill_value)
#    1239
#    1240         if new_mgr_locs is None:
#
# /usr/local/lib/python3.7/site-packages/pandas/core/algorithms.py in take_nd(arr, indexer, axis, out, fill_value, mask_info, allow_fill)
#    1647     func = _get_take_nd_function(arr.ndim, arr.dtype, out.dtype, axis=axis,
#    1648                                  mask_info=mask_info)
# -> 1649     func(arr, indexer, out, fill_value)
#    1650
#    1651     if flip_order:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Lasso Regression

# %%
lambdas = np.arange(0.01, 0.2, 0.01)
alphas = lambdas / 2

mses = [x['mse'] for x in monte_carlo(ADDITIONAL_FEATURES_SELECT, method='lasso', alpha=alphas)]

plt.plot(lambdas, mses)
plt.show()

monte_carlo(ADDITIONAL_FEATURES_SELECT, method='lasso', alpha=LAMBDA_LASSO/2)['coeffs']
# Out:
#                         1
# 0
# intercept     -0.00431199
# LotArea          0.045283
# OverallQual      0.261234
# OverallCond     0.0389292
# YearBuilt       0.0909414
# YearRemodAdd    0.0496887
# BsmtFinSF1        0.13903
# BsmtUnfSF              -0
# TotalBsmtSF      0.073512
# 1stFlrSF        0.0136454
# 2ndFlrSF                0
# GrLivArea        0.363026
# FullBath                0
# HalfBath                0
# BedroomAbvGr   -0.0359612
# TotRmsAbvGrd            0
# Fireplaces      0.0188245
# GarageCars     0.00518031
# GarageArea      0.0828019
# WoodDeckSF     0.00162681
# OpenPorchSF    0.00471648
# EnclosedPorch          -0
# Blmngtn                -0
# Blueste                -0
# BrDale                 -0
# BrkSide                 0
# ClearCr                 0
# CollgCr                -0
# Crawfor          0.021083
# Edwards                 0
# Gilbert                -0
# IDOTRR                  0
# MeadowV                 0
# Mitchel                -0
# Names                  -0
# NoRidge         0.0313394
# NPkVill                -0
# NriddgHt         0.111795
# NWAmes         -0.0185789
# OLDTown                -0
# SWISU                  -0
# Sawyer                 -0
# SawyerW       -0.00282705
# Somerst          0.019142
# StoneBr         0.0787692
# Timber                  0
# Veenker                -0
# Bsmt Qual       0.0390819
# LotFrontage     0.0128861
# LotShape               -0
# MSZoning               -0
# MSSubClass     -0.0693331

# %%
# Yvonne's for loop

lambdas = np.arange(0.01, 0.2, 0.01)
alphas = lambdas * 1800

plt.plot(lambdas, [float(shit['coeffs'].mean()) for shit in regression(ADDITIONAL_FEATURES_SELECT, method='ridge', alpha=alphas)])
plt.show()
